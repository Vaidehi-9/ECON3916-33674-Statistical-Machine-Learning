# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaidehi-9/ECON3916-33674-Statistical-Machine-Learning/blob/main/Lab%2012/%5BLab_12_%5D_OLS%2C_Hedonic_Pricing%2C_and_RMSE_Evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
from statsmodels.tools.eval_measures import rmse
import matplotlib.pyplot as plt

# Step 1: Ingestion from external source
url = 'https://raw.githubusercontent.com/Vaidehi-9/ECON3916-33674-Statistical-Machine-Learning/refs/heads/main/Data/Zillow_ZHVI_2026_Micro.csv'
df = pd.read_csv(url)

# %%
# Step 2: Defining the formula
# Utilizing the R-style patsy formula interface allows for elegant, readable model specification
formula ='Home_Value ~ Square_Footage + Property_Age + Distance_to_Transit'
# Step 3:
model   = smf.ols(formula=formula, data=df)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             Home_Value   R-squared:                       0.766
# Model:                            OLS   Adj. R-squared:                  0.765
# Method:                 Least Squares   F-statistic:                     1087.
# Date:                Mon, 16 Mar 2026   Prob (F-statistic):          1.73e-313
# Time:                        19:59:34   Log-Likelihood:                -12072.
# No. Observations:                1000   AIC:                         2.415e+04
# Df Residuals:                     996   BIC:                         2.417e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept            8.898e+04   6057.099     14.690      0.000    7.71e+04    1.01e+05
# ...

# %%
# Step 4: Generating predictions
y_pred = results.predict(df)
print(y_pred)
# Out:
# 0      312391.414318
# 1      222863.862825
# 2      333724.313631
# 3      307478.039316
# 4      392700.239719
#            ...
# 995    406484.223185
# 996    379036.577017
# 997    235603.612932
# 998    313988.849931
# 999    164006.241016
# Length: 1000, dtype: float64

# %%
model_rmse = rmse(df['Home_Value'], y_pred)
print(f"\nThe Predictive RMSE is: ${model_rmse:,.2f}")
# Out:
# The Predictive RMSE is: $42,341.60
